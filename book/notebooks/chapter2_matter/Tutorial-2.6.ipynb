# %% [markdown]
# # Landau parameters (micro)

# %% [markdown]
# In this tutorial, you will learn how to employ the microscopic module to extract Landau parameter predictions.

# %% [markdown]
# ---

# %% [markdown]
# Import the libraries that will be employed in this tutorial.

# %%
# Import numpy
import numpy as np
# Import nucleardatapy package
import nucleardatapy as nuda

# %% [markdown]
# You can simply print out the properties of the nuda's function that we will use:

# %%
# Explore the nucleardatapy module to find the correct attribute
print(dir(nuda.matter.setupMicroLP))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'init_self', 'print_outputs']

# %% [markdown]
# ---

# %% [markdown]
# Get the full list of models:

# %%
models, models_lower = nuda.matter.micro_LP_models()
print('models:',models)
# Out:
# models: ['1994-BHF-SM-LP-AV14-GAP', '1994-BHF-SM-LP-AV14-CONT', '1994-BHF-SM-LP-REID-GAP', '1994-BHF-SM-LP-REID-CONT', '1994-BHF-SM-LP-AV14-CONT-0.7', '2007-BHF-NM-LP-BONNC']

# %% [markdown]
# Fix one model for which we want to extract the data:

# %%
model = '1994-BHF-SM-LP-AV14-GAP'

# %% [markdown]
# Instantiate `lp` with the data from microscopic model defined by `model`:

# %%
lp = nuda.matter.setupMicroLP( model = model )
lp.print_outputs()
# Out:
# - Print output:
#    model:  1994-BHF-SM-LP-AV14-GAP
#    ref:    M. Baldo and L.S. Ferreira, Phys. Rev. C 50, 1887 (1994)
#    label:  BHF-AV14Gap-1994
#    marker: o
#    note:   write here notes about this EOS.
# in SM:
#    sm_kfn:  1.4
#    sm_effmass:  0.625
#    sm_effMass:  0.736
#    Ksat:  286.0
#    Esym2:  31.2
#    F: {0: np.float64(-0.267), 1: np.float64(-0.791), 2: np.float64(-0.466), 3: np.float64(-0.172), 4: np.float64(-0.121), 5: np.float64(-0.068), 6: np.float64(-0.055), 7: np.float64(-0.036)}
#    F0: -0.267
#    F0: -0.267
#    G0: 0.017
#    Fp0: 0.438
#    Gp0: 1.363
# in NM:

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# plot:

# %%
nuda.plot.matter_setupMicro_LP_fig( None, models, matter = 'SM', ell = 0 )
# Out:
# Plot name: None
#
# model: 1994-BHF-SM-LP-AV14-GAP
#
#
# model: 1994-BHF-SM-LP-AV14-CONT
#
#
# model: 1994-BHF-SM-LP-REID-GAP
#
#
# model: 1994-BHF-SM-LP-REID-CONT
#
#
# model: 1994-BHF-SM-LP-AV14-CONT-0.7

# %%
nuda.plot.matter_setupMicro_LP_fig( None, models, matter = 'SM', ell = 1 )
# Out:
# Plot name: None
#
# model: 1994-BHF-SM-LP-AV14-GAP
#
#
# model: 1994-BHF-SM-LP-AV14-CONT
#
#
# model: 1994-BHF-SM-LP-REID-GAP
#
#
# model: 1994-BHF-SM-LP-REID-CONT
#
#
# model: 1994-BHF-SM-LP-AV14-CONT-0.7

# %%
nuda.plot.matter_setupMicro_LP_fig( None, models, matter = 'NM', ell = 0 )
# Out:
# Plot name: None
#
# model: 2007-BHF-NM-LP-BONNC
