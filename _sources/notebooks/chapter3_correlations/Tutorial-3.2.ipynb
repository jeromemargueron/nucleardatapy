# %% [markdown]
# # Esym-Lsym correlation

# %% [markdown]
# In this tutorial, you will learn how to extract the Esym-Lsym correlation.

# %% [markdown]
# ---

# %% [markdown]
# Import the libraries that will be employed in this tutorial.

# %%
# Import numpy
import numpy as np
# Import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# Import nucleardatapy package
import nucleardatapy as nuda

# %% [markdown]
# You can simply print out the properties of the nuda's function that we will use:

# %%
# Explore the nucleardatapy module to find the correct attribute
print(dir(nuda.corr.setupEsymLsym))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__firstlineno__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__static_attributes__', '__str__', '__subclasshook__', '__weakref__', 'init_self', 'print_outputs']

# %% [markdown]
# ---

# %% [markdown]
# Get the full list of constraints:

# %%
constraints, constraints_lower = nuda.corr.EsymLsym_constraints()
print('constraints:',constraints)
# Out:
# constraints: ['2009-HIC', '2010-RNP', '2012-FRDM', '2013-NS', '2014-IAS', '2014-IAS+RNP', '2015-POL-208Pb', '2015-POL-120Sn', '2015-POL-68Ni', '2017-UG', '2021-PREXII-Reed', '2021-PREXII-Reinhard', '2023-PREXII+CREX-Zhang', '2023-EDF-D4', '2023-EDF-D4-IAS', '2023-EDF-D4-IAS-Rnp']

# %% [markdown]
# ---

# %% [markdown]
# Fix one model for which we want to extract the constraint:

# %%
constraint = '2014-IAS'
el = nuda.corr.setupEsymLsym( constraint = constraint )

# %% [markdown]
# print the outputs:

# %%
el.print_outputs()
# Out:
#    constraint: 2014-IAS
#    ref: Danielewicz and Lee, NPA 922, 1 (2014)
#    label: IAS-2014
#    note: Constraints from IAS.
#    plot: band_y

# %% [markdown]
# plot:

# %% [markdown]
# ---

# %%
constraints, constraints_lower = nuda.corr.EsymLsym_constraints()
print('constraints:',constraints)
# Out:
# constraints: ['2009-HIC', '2010-RNP', '2012-FRDM', '2013-NS', '2014-IAS', '2014-IAS+RNP', '2015-POL-208Pb', '2015-POL-120Sn', '2015-POL-68Ni', '2017-UG', '2021-PREXII-Reed', '2021-PREXII-Reinhard', '2023-PREXII+CREX-Zhang', '2023-EDF-D4', '2023-EDF-D4-IAS', '2023-EDF-D4-IAS-Rnp']

# %% [markdown]
# ---

# %%
nuda.fig.corr_setupEsymLsym_fig( pname=None, constraints = constraints, origine = 'finiteNuclei' )
# Out:
# Plot name: None
# list of constraints: ['2009-HIC', '2010-RNP', '2012-FRDM', '2013-NS', '2014-IAS', '2014-IAS+RNP', '2015-POL-208Pb', '2015-POL-120Sn', '2015-POL-68Ni', '2017-UG', '2021-PREXII-Reed', '2021-PREXII-Reinhard', '2023-PREXII+CREX-Zhang', '2023-EDF-D4', '2023-EDF-D4-IAS', '2023-EDF-D4-IAS-Rnp']
# constraint: 2009-HIC
# constraint: 2010-RNP
# constraint: 2012-FRDM
# constraint: 2013-NS
# constraint: 2014-IAS
# constraint: 2014-IAS+RNP
# constraint: 2015-POL-208Pb
# constraint: 2015-POL-120Sn
# constraint: 2015-POL-68Ni
# constraint: 2017-UG
# constraint: 2021-PREXII-Reed
# constraint: 2021-PREXII-Reinhard
# constraint: 2023-PREXII+CREX-Zhang
# constraint: 2023-EDF-D4
# plot: contour
# Esym: [29.85, 31.97, 33.06, 37.26, 39.42, 38.58, 36.44, 30.97, 29.85]
# Lsym: [50.3, 45.36, 55.45, 99.14, 126.6, 124.57, 115.71, 61.79, 50.3]
# constraint: 2023-EDF-D4-IAS
# plot: contour
# Esym: [29.85, 31.97, 33.06, 33.96, 34.54, 30.97, 29.85]
# Lsym: [50.3, 45.36, 55.45, 71.55, 88.03, 61.79, 50.3]
# constraint: 2023-EDF-D4-IAS-Rnp
# plot: contour
# Esym: [29.85, 32.01, 32.54, 32.74, 31.98, 30.97, 29.85]
# Lsym: [50.3, 48.15, 61.52, 70.45, 67.44, 61.79, 50.3]

# %%
nuda.fig.corr_setupEsymLsym_fig( pname=None, constraints = constraints, origine = 'neutronStar')
# Out:
# Plot name: None
# list of constraints: ['2009-HIC', '2010-RNP', '2012-FRDM', '2013-NS', '2014-IAS', '2014-IAS+RNP', '2015-POL-208Pb', '2015-POL-120Sn', '2015-POL-68Ni', '2017-UG', '2021-PREXII-Reed', '2021-PREXII-Reinhard', '2023-PREXII+CREX-Zhang', '2023-EDF-D4', '2023-EDF-D4-IAS', '2023-EDF-D4-IAS-Rnp']
# constraint: 2009-HIC
# constraint: 2010-RNP
# constraint: 2012-FRDM
# constraint: 2013-NS
# constraint: 2014-IAS
# constraint: 2014-IAS+RNP
# constraint: 2015-POL-208Pb
# constraint: 2015-POL-120Sn
# constraint: 2015-POL-68Ni
# constraint: 2017-UG
# constraint: 2021-PREXII-Reed
# constraint: 2021-PREXII-Reinhard
# constraint: 2023-PREXII+CREX-Zhang
# constraint: 2023-EDF-D4
# plot: contour
# Esym: [29.85, 31.97, 33.06, 37.26, 39.42, 38.58, 36.44, 30.97, 29.85]
# Lsym: [50.3, 45.36, 55.45, 99.14, 126.6, 124.57, 115.71, 61.79, 50.3]
# constraint: 2023-EDF-D4-IAS
# plot: contour
# Esym: [29.85, 31.97, 33.06, 33.96, 34.54, 30.97, 29.85]
# Lsym: [50.3, 45.36, 55.45, 71.55, 88.03, 61.79, 50.3]
# constraint: 2023-EDF-D4-IAS-Rnp
# plot: contour
# Esym: [29.85, 32.01, 32.54, 32.74, 31.98, 30.97, 29.85]
# Lsym: [50.3, 48.15, 61.52, 70.45, 67.44, 61.79, 50.3]
