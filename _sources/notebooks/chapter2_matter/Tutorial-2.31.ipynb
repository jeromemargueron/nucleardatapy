# %% [markdown]
# # Figures with micro and pheno together

# %% [markdown]
# In this tutorial, you will learn how to employ nucleardatapy to draw figures shownign results from micro nd pheno together.

# %% [markdown]
# ---

# %% [markdown]
# Import the libraries that will be employed in this tutorial.

# %%
# Import numpy
import numpy as np
# Import matplotlib
import matplotlib.pyplot as plt
# Import nucleardatapy package
import nucleardatapy as nuda
# %matplotlib inline

# %% [markdown]
# ---

# %% [markdown]
# plot energy per particle in NM:

# %%
den = np.array([0.04,0.06,0.08,0.1,0.12,0.14,0.16])
models = [ '2016-MBPT-AM', '2016-QMC-NM', '2020-MBPT-AM' ]
band = nuda.matter.setupMicroBand( models, den=den, matter='NM' )
micro_mbs, micro_mbs_lower = nuda.matter.micro_mbs()
pheno_models = [ 'Skyrme', 'NLRH', 'DDRH', 'DDRHF' ]
# nuda.fig.matter_ENM_fig( None, micro_mbs, pheno_models, band )
# Out:
# Band in NM
# model ->  2016-MBPT-AM
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# model ->  2016-QMC-NM
# flag_nm: True
# flag_sm: False
# flag_kf: True
# flag_den: False
# model ->  2020-MBPT-AM
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# model ->  2016-MBPT-AM
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# model ->  2016-QMC-NM
# flag_nm: True
# flag_sm: False
# flag_kf: True
# flag_den: False
# model ->  2020-MBPT-AM
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True

# %% [markdown]
# plot energy per particle in SM:

# %%
den = np.array([0.04,0.06,0.08,0.1,0.12,0.14,0.16])
models = [ '2016-MBPT-AM', '2020-MBPT-AM' ]
band = nuda.matter.setupMicroBand( models, den=den, matter='SM' )
micro_mbs, micro_mbs_lower = nuda.matter.micro_esym_mbs()
pheno_models = [ 'Skyrme', 'NLRH', 'DDRH', 'DDRHF' ]
nuda.fig.matter_all_e2a_fig( None, micro_mbs, pheno_models, band, band, matter='SM' )
# Out:
# Band in SM
# model ->  2016-MBPT-AM
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# model ->  2020-MBPT-AM
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# model ->  2016-MBPT-AM
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# model ->  2020-MBPT-AM
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# Plot name: None
# models in matter code: ['1981-VAR-AM-FP', '1998-VAR-AM-APR', '1998-VAR-AM-APR-fit']
# model ->  1981-VAR-AM-FP
# flag_nm: True
# flag_sm: True
# flag_kf: True
# flag_den: False
# mb: VAR model: 1981-VAR-AM-FP
# with marker 2: o
# with no error False
# model ->  1998-VAR-AM-APR
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: VAR model: 1998-VAR-AM-APR
# with marker 1: ^
# with no error False
# models in matter code: ['2024-BHF-AM-2BF-Av18', '2024-BHF-AM-2BF-BONN', '2024-BHF-AM-2BF-CDBONN', '2024-BHF-AM-2BF-NSC97a', '2024-BHF-AM-2BF-NSC97b', '2024-BHF-AM-2BF-NSC97c', '2024-BHF-AM-2BF-NSC97d', '2024-BHF-AM-2BF-NSC97e', '2024-BHF-AM-2BF-NSC97f']
# model ->  2024-BHF-AM-2BF-Av18
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF2 model: 2024-BHF-AM-2BF-Av18
# with marker 2: o
# with no error False
# model ->  2024-BHF-AM-2BF-BONN
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF2 model: 2024-BHF-AM-2BF-BONN
# with marker 1: o
# with no error False
# model ->  2024-BHF-AM-2BF-CDBONN
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF2 model: 2024-BHF-AM-2BF-CDBONN
# with marker 1: o
# with no error False
# model ->  2024-BHF-AM-2BF-NSC97a
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF2 model: 2024-BHF-AM-2BF-NSC97a
# with marker 1: o
# with no error False
# model ->  2024-BHF-AM-2BF-NSC97b
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF2 model: 2024-BHF-AM-2BF-NSC97b
# with marker 1: o
# with no error False
# model ->  2024-BHF-AM-2BF-NSC97c
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF2 model: 2024-BHF-AM-2BF-NSC97c
# with marker 1: o
# with no error False
# model ->  2024-BHF-AM-2BF-NSC97d
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF2 model: 2024-BHF-AM-2BF-NSC97d
# with marker 1: o
# with no error False
# model ->  2024-BHF-AM-2BF-NSC97e
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF2 model: 2024-BHF-AM-2BF-NSC97e
# with marker 1: o
# with no error False
# model ->  2024-BHF-AM-2BF-NSC97f
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF2 model: 2024-BHF-AM-2BF-NSC97f
# with marker 1: o
# with no error False
# models in matter code: ['2006-BHF-AM-Av18', '2024-BHF-AM-23BF-Av18', '2024-BHF-AM-23BF-BONN', '2024-BHF-AM-23BF-CDBONN', '2024-BHF-AM-23BF-NSC97a', '2024-BHF-AM-23BF-NSC97b', '2024-BHF-AM-23BF-NSC97c', '2024-BHF-AM-23BF-NSC97d', '2024-BHF-AM-23BF-NSC97e', '2024-BHF-AM-23BF-NSC97f']
# model ->  2006-BHF-AM-Av18
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF23 model: 2006-BHF-AM-Av18
# with marker 2: o
# with no error False
# model ->  2024-BHF-AM-23BF-Av18
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF23 model: 2024-BHF-AM-23BF-Av18
# with marker 1: o
# with no error False
# model ->  2024-BHF-AM-23BF-BONN
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF23 model: 2024-BHF-AM-23BF-BONN
# with marker 1: o
# with no error False
# model ->  2024-BHF-AM-23BF-CDBONN
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF23 model: 2024-BHF-AM-23BF-CDBONN
# with marker 1: o
# with no error False
# model ->  2024-BHF-AM-23BF-NSC97a
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF23 model: 2024-BHF-AM-23BF-NSC97a
# with marker 1: o
# with no error False
# model ->  2024-BHF-AM-23BF-NSC97b
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF23 model: 2024-BHF-AM-23BF-NSC97b
# with marker 1: o
# with no error False
# model ->  2024-BHF-AM-23BF-NSC97c
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF23 model: 2024-BHF-AM-23BF-NSC97c
# with marker 1: o
# with no error False
# model ->  2024-BHF-AM-23BF-NSC97d
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF23 model: 2024-BHF-AM-23BF-NSC97d
# with marker 1: o
# with no error False
# model ->  2024-BHF-AM-23BF-NSC97e
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF23 model: 2024-BHF-AM-23BF-NSC97e
# with marker 1: o
# with no error False
# model ->  2024-BHF-AM-23BF-NSC97f
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF23 model: 2024-BHF-AM-23BF-NSC97f
# with marker 1: o
# with no error False
# models in matter code: ['2013-MBPT-NM', '2016-MBPT-AM', '2019-MBPT-AM-L59', '2019-MBPT-AM-L69', '2020-MBPT-AM', '2024-MBPT-AM-DN2LO-450', '2024-MBPT-AM-DN2LO-500', '2024-MBPT-AM-DN2LOgo-394', '2024-MBPT-AM-DN2LOgo-450', '2024-MBPT-AM-N2LOsat']
# model ->  2016-MBPT-AM
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: MBPT model: 2016-MBPT-AM
# with marker 2: s
# with error True
# model ->  2019-MBPT-AM-L59
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: MBPT model: 2019-MBPT-AM-L59
# with marker 1: s
# with no error False
# model ->  2019-MBPT-AM-L69
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: MBPT model: 2019-MBPT-AM-L69
# with marker 1: s
# with no error False
# model ->  2020-MBPT-AM
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: MBPT model: 2020-MBPT-AM
# with marker 1: o
# with error True
# model ->  2024-MBPT-AM-DN2LO-450
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: MBPT model: 2024-MBPT-AM-DN2LO-450
# with marker 1: x
# with no error False
# model ->  2024-MBPT-AM-DN2LO-500
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: MBPT model: 2024-MBPT-AM-DN2LO-500
# with marker 1: x
# with no error False
# model ->  2024-MBPT-AM-DN2LOgo-394
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: MBPT model: 2024-MBPT-AM-DN2LOgo-394
# with marker 1: x
# with no error False
# model ->  2024-MBPT-AM-DN2LOgo-450
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: MBPT model: 2024-MBPT-AM-DN2LOgo-450
# with marker 1: x
# with no error False
# model ->  2024-MBPT-AM-N2LOsat
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: MBPT model: 2024-MBPT-AM-N2LOsat
# with marker 1: x
# with no error False
# models in matter code: ['2024-NLEFT-AM']
# model ->  2024-NLEFT-AM
# sm_popt: [-9.17066389 10.01180306 -3.0695997 ]
# sm_pcov: [[ 0.50462836 -0.83636896  0.34040806]
#  [-0.83636896  1.40263142 -0.5763757 ]
#  [ 0.34040806 -0.5763757   0.23873678]]
# nm_popt: [-1.18794133  0.71930878 -0.11294907]
# nm_pcov: [[ 0.01360533 -0.01702127  0.00515285]
#  [-0.01702127  0.02165016 -0.00663766]
#  [ 0.00515285 -0.00663766  0.00205604]]
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: False
# mb: NLEFT model: 2024-NLEFT-AM
# with marker 2: s
# with error True
# models in matter code: ['2020-SCGF-AM-N3LO-414', '2020-SCGF-AM-N3LO-450', '2020-SCGF-AM-N3LO-500', '2024-SCGF-AM-DN2LO-450', '2024-SCGF-AM-DN2LO-500', '2024-SCGF-AM-DN2LOgo-394', '2024-SCGF-AM-DN2LOgo-450', '2024-SCGF-AM-N2LOsat']
# model ->  2020-SCGF-AM-N3LO-414
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: SCGF model: 2020-SCGF-AM-N3LO-414
# with marker 2: +
# with no error False
# model ->  2020-SCGF-AM-N3LO-450
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: SCGF model: 2020-SCGF-AM-N3LO-450
# with marker 1: +
# with no error False
# model ->  2020-SCGF-AM-N3LO-500
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: SCGF model: 2020-SCGF-AM-N3LO-500
# with marker 1: +
# with no error False
# model ->  2024-SCGF-AM-DN2LO-450
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: SCGF model: 2024-SCGF-AM-DN2LO-450
# with marker 1: x
# with no error False
# model ->  2024-SCGF-AM-DN2LO-500
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: SCGF model: 2024-SCGF-AM-DN2LO-500
# with marker 1: x
# with no error False
# model ->  2024-SCGF-AM-DN2LOgo-394
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: SCGF model: 2024-SCGF-AM-DN2LOgo-394
# with marker 1: x
# with no error False
# model ->  2024-SCGF-AM-DN2LOgo-450
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: SCGF model: 2024-SCGF-AM-DN2LOgo-450
# with marker 1: x
# with no error False
# model ->  2024-SCGF-AM-N2LOsat
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: SCGF model: 2024-SCGF-AM-N2LOsat
# with marker 1: x
# with no error False
# models in matter code: ['2024-CC-AM-DN2LO-450', '2024-CC-AM-DN2LO-500', '2024-CC-AM-DN2LOgo-394', '2024-CC-AM-DN2LOgo-450', '2024-CC-AM-N2LOsat']
# model ->  2024-CC-AM-DN2LO-450
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: CC model: 2024-CC-AM-DN2LO-450
# with marker 2: x
# with no error False
# model ->  2024-CC-AM-DN2LO-500
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: CC model: 2024-CC-AM-DN2LO-500
# with marker 1: x
# with no error False
# model ->  2024-CC-AM-DN2LOgo-394
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: CC model: 2024-CC-AM-DN2LOgo-394
# with marker 1: x
# with no error False
# model ->  2024-CC-AM-DN2LOgo-450
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: CC model: 2024-CC-AM-DN2LOgo-450
# with marker 1: x
# with no error False
# model ->  2024-CC-AM-N2LOsat
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: CC model: 2024-CC-AM-N2LOsat
# with marker 1: x
# with no error False
# model: Skyrme  param: BSK14
# model: Skyrme  param: BSK16
# model: Skyrme  param: BSK17
# model: Skyrme  param: BSK27
# model: Skyrme  param: BSkG1
# model: Skyrme  param: BSkG2
# model: Skyrme  param: F-
# model: Skyrme  param: F+
# model: Skyrme  param: F0
# model: Skyrme  param: FPL
# model: Skyrme  param: LNS
# model: Skyrme  param: LNS1
# model: Skyrme  param: LNS5
# model: Skyrme  param: NRAPR
# model: Skyrme  param: RATP
# model: Skyrme  param: SAMI
# model: Skyrme  param: SGII
# model: Skyrme  param: SIII
# model: Skyrme  param: SKGSIGMA
# model: Skyrme  param: SKI2
# model: Skyrme  param: SKI4
# model: Skyrme  param: SKMP
# model: Skyrme  param: SKMS
# model: Skyrme  param: SKO
# model: Skyrme  param: SKOP
# model: Skyrme  param: SKP
# model: Skyrme  param: SKRSIGMA
# model: Skyrme  param: SKX
# model: Skyrme  param: Skz2
# model: Skyrme  param: SLY4
# model: Skyrme  param: SLY5
# model: Skyrme  param: SLY230A
# model: Skyrme  param: SLY230B
# model: Skyrme  param: SV
# model: Skyrme  param: T6
# model: Skyrme  param: T44
# model: Skyrme  param: UNEDF0
# model: Skyrme  param: UNEDF1
# model: NLRH  param: NL-SH
# model: NLRH  param: NL3
# model: NLRH  param: NL3II
# model: NLRH  param: PK1
# model: NLRH  param: PK1R
# model: NLRH  param: TM1
# model: DDRH  param: DDME1
# model: DDRH  param: DDME2
# model: DDRH  param: DDMEd
# model: DDRH  param: PKDD
# model: DDRH  param: TW99
# model: DDRHF  param: PKA1
# model: DDRHF  param: PKO1
# model: DDRHF  param: PKO2
# model: DDRHF  param: PKO3

# %% [markdown]
# ---

# %% [markdown]
# Plot the symmetry energy:

# %%
den = np.array([0.04,0.06,0.08,0.1,0.12,0.14,0.16])
models = [ '2016-MBPT-AM', '2020-MBPT-AM' ]
band = nuda.matter.setupMicroBand( models, den=den, matter='ESYM' )
micro_mbs, micro_mbs_lower = nuda.matter.micro_esym_mbs()
pheno_models = [ 'Skyrme', 'NLRH', 'DDRH', 'DDRHF' ]
nuda.fig.matter_all_Esym_fig( pname=None, micro_mbs=micro_mbs, pheno_models=pheno_models, band_check=band, band_plot=band )
# Out:
# Band for Esym
# model ->  2016-MBPT-AM
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# -> model: 2016-MBPT-AM
# model ->  2016-MBPT-AM
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# model ->  2020-MBPT-AM
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# -> model: 2020-MBPT-AM
# model ->  2020-MBPT-AM
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# model ->  2016-MBPT-AM
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# -> model: 2016-MBPT-AM
# model ->  2016-MBPT-AM
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# model ->  2020-MBPT-AM
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# -> model: 2020-MBPT-AM
# model ->  2020-MBPT-AM
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# Plot name: None
# -> model: 1981-VAR-AM-FP
# model ->  1981-VAR-AM-FP
# flag_nm: True
# flag_sm: True
# flag_kf: True
# flag_den: False
# mb: VAR model: 1981-VAR-AM-FP
# -> model: 1998-VAR-AM-APR
# model ->  1998-VAR-AM-APR
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: VAR model: 1998-VAR-AM-APR
# -> model: 2024-BHF-AM-2BF-Av18
# model ->  2024-BHF-AM-2BF-Av18
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF2 model: 2024-BHF-AM-2BF-Av18
# -> model: 2024-BHF-AM-2BF-BONN
# model ->  2024-BHF-AM-2BF-BONN
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF2 model: 2024-BHF-AM-2BF-BONN
# -> model: 2024-BHF-AM-2BF-CDBONN
# model ->  2024-BHF-AM-2BF-CDBONN
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF2 model: 2024-BHF-AM-2BF-CDBONN
# -> model: 2024-BHF-AM-2BF-NSC97a
# model ->  2024-BHF-AM-2BF-NSC97a
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF2 model: 2024-BHF-AM-2BF-NSC97a
# -> model: 2024-BHF-AM-2BF-NSC97b
# model ->  2024-BHF-AM-2BF-NSC97b
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF2 model: 2024-BHF-AM-2BF-NSC97b
# -> model: 2024-BHF-AM-2BF-NSC97c
# model ->  2024-BHF-AM-2BF-NSC97c
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF2 model: 2024-BHF-AM-2BF-NSC97c
# -> model: 2024-BHF-AM-2BF-NSC97d
# model ->  2024-BHF-AM-2BF-NSC97d
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF2 model: 2024-BHF-AM-2BF-NSC97d
# -> model: 2024-BHF-AM-2BF-NSC97e
# model ->  2024-BHF-AM-2BF-NSC97e
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF2 model: 2024-BHF-AM-2BF-NSC97e
# -> model: 2024-BHF-AM-2BF-NSC97f
# model ->  2024-BHF-AM-2BF-NSC97f
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF2 model: 2024-BHF-AM-2BF-NSC97f
# -> model: 2006-BHF-AM-Av18
# model ->  2006-BHF-AM-Av18
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF23 model: 2006-BHF-AM-Av18
# -> model: 2024-BHF-AM-23BF-Av18
# model ->  2024-BHF-AM-23BF-Av18
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF23 model: 2024-BHF-AM-23BF-Av18
# -> model: 2024-BHF-AM-23BF-BONN
# model ->  2024-BHF-AM-23BF-BONN
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF23 model: 2024-BHF-AM-23BF-BONN
# -> model: 2024-BHF-AM-23BF-CDBONN
# model ->  2024-BHF-AM-23BF-CDBONN
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF23 model: 2024-BHF-AM-23BF-CDBONN
# -> model: 2024-BHF-AM-23BF-NSC97a
# model ->  2024-BHF-AM-23BF-NSC97a
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF23 model: 2024-BHF-AM-23BF-NSC97a
# -> model: 2024-BHF-AM-23BF-NSC97b
# model ->  2024-BHF-AM-23BF-NSC97b
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF23 model: 2024-BHF-AM-23BF-NSC97b
# -> model: 2024-BHF-AM-23BF-NSC97c
# model ->  2024-BHF-AM-23BF-NSC97c
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF23 model: 2024-BHF-AM-23BF-NSC97c
# -> model: 2024-BHF-AM-23BF-NSC97d
# model ->  2024-BHF-AM-23BF-NSC97d
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF23 model: 2024-BHF-AM-23BF-NSC97d
# -> model: 2024-BHF-AM-23BF-NSC97e
# model ->  2024-BHF-AM-23BF-NSC97e
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF23 model: 2024-BHF-AM-23BF-NSC97e
# -> model: 2024-BHF-AM-23BF-NSC97f
# model ->  2024-BHF-AM-23BF-NSC97f
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: BHF23 model: 2024-BHF-AM-23BF-NSC97f
# -> model: 2019-MBPT-AM-L59
# model ->  2019-MBPT-AM-L59
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: MBPT model: 2019-MBPT-AM-L59
# -> model: 2016-MBPT-AM
# model ->  2016-MBPT-AM
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: MBPT model: 2016-MBPT-AM
# -> model: 2019-MBPT-AM-L69
# model ->  2019-MBPT-AM-L69
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: MBPT model: 2019-MBPT-AM-L69
# -> model: 2020-MBPT-AM
# model ->  2020-MBPT-AM
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: MBPT model: 2020-MBPT-AM
# -> model: 2024-MBPT-AM-DN2LO-450
# model ->  2024-MBPT-AM-DN2LO-450
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: MBPT model: 2024-MBPT-AM-DN2LO-450
# -> model: 2024-MBPT-AM-DN2LO-500
# model ->  2024-MBPT-AM-DN2LO-500
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: MBPT model: 2024-MBPT-AM-DN2LO-500
# -> model: 2024-MBPT-AM-DN2LOgo-394
# model ->  2024-MBPT-AM-DN2LOgo-394
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: MBPT model: 2024-MBPT-AM-DN2LOgo-394
# -> model: 2024-MBPT-AM-DN2LOgo-450
# model ->  2024-MBPT-AM-DN2LOgo-450
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: MBPT model: 2024-MBPT-AM-DN2LOgo-450
# -> model: 2024-MBPT-AM-N2LOsat
# model ->  2024-MBPT-AM-N2LOsat
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: MBPT model: 2024-MBPT-AM-N2LOsat
# -> model: 2024-NLEFT-AM
# model ->  2024-NLEFT-AM
# sm_popt: [-9.17066389 10.01180306 -3.0695997 ]
# sm_pcov: [[ 0.50462836 -0.83636896  0.34040806]
#  [-0.83636896  1.40263142 -0.5763757 ]
#  [ 0.34040806 -0.5763757   0.23873678]]
# nm_popt: [-1.18794133  0.71930878 -0.11294907]
# nm_pcov: [[ 0.01360533 -0.01702127  0.00515285]
#  [-0.01702127  0.02165016 -0.00663766]
#  [ 0.00515285 -0.00663766  0.00205604]]
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: False
# mb: NLEFT model: 2024-NLEFT-AM
# -> model: 2020-SCGF-AM-N3LO-414
# model ->  2020-SCGF-AM-N3LO-414
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: SCGF model: 2020-SCGF-AM-N3LO-414
# -> model: 2020-SCGF-AM-N3LO-450
# model ->  2020-SCGF-AM-N3LO-450
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: SCGF model: 2020-SCGF-AM-N3LO-450
# -> model: 2020-SCGF-AM-N3LO-500
# model ->  2020-SCGF-AM-N3LO-500
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: SCGF model: 2020-SCGF-AM-N3LO-500
# -> model: 2024-SCGF-AM-DN2LO-450
# model ->  2024-SCGF-AM-DN2LO-450
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: SCGF model: 2024-SCGF-AM-DN2LO-450
# -> model: 2024-SCGF-AM-DN2LO-500
# model ->  2024-SCGF-AM-DN2LO-500
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: SCGF model: 2024-SCGF-AM-DN2LO-500
# -> model: 2024-SCGF-AM-DN2LOgo-394
# model ->  2024-SCGF-AM-DN2LOgo-394
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: SCGF model: 2024-SCGF-AM-DN2LOgo-394
# -> model: 2024-SCGF-AM-DN2LOgo-450
# model ->  2024-SCGF-AM-DN2LOgo-450
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: SCGF model: 2024-SCGF-AM-DN2LOgo-450
# -> model: 2024-SCGF-AM-N2LOsat
# model ->  2024-SCGF-AM-N2LOsat
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: SCGF model: 2024-SCGF-AM-N2LOsat
# -> model: 2024-CC-AM-DN2LO-450
# model ->  2024-CC-AM-DN2LO-450
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: CC model: 2024-CC-AM-DN2LO-450
# -> model: 2024-CC-AM-DN2LO-500
# model ->  2024-CC-AM-DN2LO-500
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: CC model: 2024-CC-AM-DN2LO-500
# -> model: 2024-CC-AM-DN2LOgo-394
# model ->  2024-CC-AM-DN2LOgo-394
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: CC model: 2024-CC-AM-DN2LOgo-394
# -> model: 2024-CC-AM-DN2LOgo-450
# model ->  2024-CC-AM-DN2LOgo-450
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: CC model: 2024-CC-AM-DN2LOgo-450
# -> model: 2024-CC-AM-N2LOsat
# model ->  2024-CC-AM-N2LOsat
# flag_nm: True
# flag_sm: True
# flag_kf: False
# flag_den: True
# mb: CC model: 2024-CC-AM-N2LOsat
# model: Skyrme  param: BSK14
# model: Skyrme  param: BSK16
# model: Skyrme  param: BSK17
# model: Skyrme  param: BSK27
# model: Skyrme  param: BSkG1
# model: Skyrme  param: BSkG2
# model: Skyrme  param: F-
# model: Skyrme  param: F+
# model: Skyrme  param: F0
# model: Skyrme  param: FPL
# model: Skyrme  param: LNS
# model: Skyrme  param: LNS1
# model: Skyrme  param: LNS5
# model: Skyrme  param: NRAPR
# model: Skyrme  param: RATP
# model: Skyrme  param: SAMI
# model: Skyrme  param: SGII
# model: Skyrme  param: SIII
# model: Skyrme  param: SKGSIGMA
# model: Skyrme  param: SKI2
# model: Skyrme  param: SKI4
# model: Skyrme  param: SKMP
# model: Skyrme  param: SKMS
# model: Skyrme  param: SKO
# model: Skyrme  param: SKOP
# model: Skyrme  param: SKP
# model: Skyrme  param: SKRSIGMA
# model: Skyrme  param: SKX
# model: Skyrme  param: Skz2
# model: Skyrme  param: SLY4
# model: Skyrme  param: SLY5
# model: Skyrme  param: SLY230A
# model: Skyrme  param: SLY230B
# model: Skyrme  param: SV
# model: Skyrme  param: T6
# model: Skyrme  param: T44
# model: Skyrme  param: UNEDF0
# model: Skyrme  param: UNEDF1
# model: NLRH  param: NL-SH
# model: NLRH  param: NL3
# model: NLRH  param: NL3II
# model: NLRH  param: PK1
# model: NLRH  param: PK1R
# model: NLRH  param: TM1
# model: DDRH  param: DDME1
# model: DDRH  param: DDME2
# model: DDRH  param: DDMEd
# model: DDRH  param: PKDD
# model: DDRH  param: TW99
# model: DDRHF  param: PKA1
# model: DDRHF  param: PKO1
# model: DDRHF  param: PKO2
# model: DDRHF  param: PKO3
